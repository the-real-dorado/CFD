# %%
import CFD

# %%
file = 'meshes/circle.obj'
domain = CFD.domain(file,1/1000,1000,500,display=True)
# Out:
# Building domain

# %%
fluid = CFD.fluid(domain)
bc = CFD.models.flow(domain,10,0)

# %%
CFD.simulation(fluid,bc)
# Out:
# Initializing
# time-step: 1e-06
# max iterations: 1000
# max delta-KE: 0.001
# Solving
# iteration: 1000 | abs delta-KE: 0.00521 | elapsed time: 2m 34s

# %%
CFD.data.plot(fluid,['pressure'],path='plots/')
CFD.data.plot(fluid,['velocity','streamlines'],path='plots/')
